# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Жопа" data-toc-modified-id="Жопа-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Жопа</a></span></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#dfgdf" data-toc-modified-id="dfgdf-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>dfgdf</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров-квартир:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Изучение-параметров-квартир:-площадь,-цена,-число-комнат,-высота-потолков.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Изучение параметров квартир: площадь, цена, число комнат, высота потолков.</a></span></li><li><span><a href="#Изучение-времени-продажи-квартир" data-toc-modified-id="Изучение-времени-продажи-квартир-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Изучение времени продажи квартир</a></span></li><li><span><a href="#Удаление-редких-и-выбивающихся-значений" data-toc-modified-id="Удаление-редких-и-выбивающихся-значений-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Удаление редких и выбивающихся значений</a></span></li><li><span><a href="#Исследование-факторов-наиболее-влияющих-на-стоимость-квартир" data-toc-modified-id="Исследование-факторов-наиболее-влияющих-на-стоимость-квартир-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Исследование факторов наиболее влияющих на стоимость квартир</a></span><ul class="toc-item"><li><span><a href="#Влияние-площади-недвижимости-на-цену-за-квадратный-метр" data-toc-modified-id="Влияние-площади-недвижимости-на-цену-за-квадратный-метр-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Влияние площади недвижимости на цену за квадратный метр</a></span></li><li><span><a href="#Влияние-количества-комнат-недвижимости-на-цену-за-квадратный-метр" data-toc-modified-id="Влияние-количества-комнат-недвижимости-на-цену-за-квадратный-метр-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Влияние количества комнат недвижимости на цену за квадратный метр</a></span></li><li><span><a href="#Влияние-расстояния-недвижимости-до-центра-города-на-цену-за-квадратный-метр" data-toc-modified-id="Влияние-расстояния-недвижимости-до-центра-города-на-цену-за-квадратный-метр-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Влияние расстояния недвижимости до центра города на цену за квадратный метр</a></span></li><li><span><a href="#Влияние-этажа-на-цену-за-квадратный-метр" data-toc-modified-id="Влияние-этажа-на-цену-за-квадратный-метр-5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>Влияние этажа на цену за квадратный метр</a></span></li><li><span><a href="#Влияние-дня-недели-размещения-объявления-на-цену-за-квадратный-метр" data-toc-modified-id="Влияние-дня-недели-размещения-объявления-на-цену-за-квадратный-метр-5.4.5"><span class="toc-item-num">5.4.5&nbsp;&nbsp;</span>Влияние дня недели размещения объявления на цену за квадратный метр</a></span></li><li><span><a href="#Влияние-месяца-размещения-объявления-на-цену-за-квадратный-метр" data-toc-modified-id="Влияние-месяца-размещения-объявления-на-цену-за-квадратный-метр-5.4.6"><span class="toc-item-num">5.4.6&nbsp;&nbsp;</span>Влияние месяца размещения объявления на цену за квадратный метр</a></span></li><li><span><a href="#Влияние-года-размещения-объявления-на-цену-за-квадратный-метр" data-toc-modified-id="Влияние-года-размещения-объявления-на-цену-за-квадратный-метр-5.4.7"><span class="toc-item-num">5.4.7&nbsp;&nbsp;</span>Влияние года размещения объявления на цену за квадратный метр</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследование-цен-на-недвижимость-в-Санкт_Петербурге" data-toc-modified-id="Исследование-цен-на-недвижимость-в-Санкт_Петербурге-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследование цен на недвижимость в Санкт_Петербурге</a></span><ul class="toc-item"><li><span><a href="#Определение-центра-СПБ" data-toc-modified-id="Определение-центра-СПБ-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Определение центра СПБ</a></span></li><li><span><a href="#Исследование-факторов-наиболее-влияющих-на-стоимость-квартир-в-СПБ" data-toc-modified-id="Исследование-факторов-наиболее-влияющих-на-стоимость-квартир-в-СПБ-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Исследование факторов наиболее влияющих на стоимость квартир в СПБ</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# ## Жопа

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_columns' , 35)
df = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.head(15)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
#я выбрал groupby, а не value_counts, потому что мне нужна сортировка по значениям, а не кол-ву
#df.groupby('ceiling_height')['ceiling_height'].count().tail(15)
#df.groupby('days_exposition')['days_exposition'].count().tail(10)
#df.groupby('last_price')['last_price'].count()
#df.groupby('living_area')['living_area'].count()
#df.groupby('kitchen_area')['kitchen_area'].count()

# %%
df.isna().mean().mean()
# Out:
# 0.19456325353198636

# %% [markdown]
# ### Вывод

# %% [markdown]
# Почти 20% пропусков в датафрейме, в предобработке рассмотрим их внимательнее.
# В таблице имеются аномальные значения:
# * неправдоподобная высота потолков; (скорее всего тут просто опечатка, м.б. показатели в дм, а не м)
# * неоправданно долгие сроки объявлений; (так же, как и пропуски в этом столбце, тут просто не сняли объявление после продажи)
# * слишком низкая цена на квартиру( цена в 800кк существует, а вот 12к- похоже на аренду или ошибку)
# * площади кухни и жилой части в некоторых строчках подозрительно малы. (теория с апартаментами отпала, так что мне непонятна причина)
#
# Так же, для удобства стоит сменить типы данных 'first_day_exposition', 'floors_total', 'is_apartment', 'balcony', 'parks/ponds_around3000' и 'days_exposition'

# %% [markdown]
# ## Предобработка данных

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# ### dfgdf

# %% [markdown]
# * ceiling_height- можно попробовать заменить на медианное значение по дальности от центра
# * cityCenters_nearest попробуем заменить на среднее значение по населенному пункту
# * living_area и kitchen_area оставим как есть, эти данные сложно на что-то заменить
# * георгафические данные пропущены

# %%
df[df['locality_name'].isna()].head() # непонятно, почему тут пропуски
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1097             3   8600000.0        81.7  2016-04-15T00:00:00      3
# 2033             6   5398000.0        80.0  2017-05-30T00:00:00      3
# 2603            20   3351765.0        42.7  2015-09-20T00:00:00      1
# 2632             2   5130593.0        62.4  2015-10-11T00:00:00      2
# 3574            10   4200000.0        46.5  2016-05-28T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 1097            3.55           5.0         50.8      2          NaN   False
# 2033             NaN           4.0         42.6      2          NaN   False
# 2603             NaN          24.0         15.6      3          NaN   False
# 2632             NaN          24.0         33.1     21          NaN   False
# 3574             NaN           5.0         30.8      5          NaN   False
#
#       open_plan  kitchen_area  balcony locality_name  airports_nearest  \
# ...

# %%
df[df['floors_total'].isna()] #Никакой закономерности в пропусках нет, данные пропущены не только на первом/последнем этажах
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 186              12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237               4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457               4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671               4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757              5   3600000.0        39.0  2017-04-22T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 22542             5   8500000.0        63.5  2017-05-24T00:00:00      2
# 22656             4   4574160.0        64.5  2017-04-02T00:00:00      2
# 22808             0  14569263.0       110.4  2016-11-20T00:00:00      3
# 23590             0  21187872.0       123.3  2017-04-25T00:00:00      3
# 23658             6   3063600.0        43.8  2016-11-28T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
#Добавлю столбец с округленным растоянием до центра города в км (далее он нам тоже пригодится)
df['until_center_km'] = round(df['cityCenters_nearest'] / 1000)

# %%
#Так как застройка типовая, то предположительно высота потолков в 9ти и 5ти этажках одинаковая
df['ceiling_height'] = df['ceiling_height'].fillna(df
                        .groupby('floors_total')['ceiling_height']
                        .transform('median')
                        )

# %%
df['ceiling_height'] = df['ceiling_height'].where(df['ceiling_height'] < 10, df['ceiling_height'] /10)

# %%
df['ceiling_height'].isna().sum()
# Out:
# 78

# %%
df[df['days_exposition'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 7                 5   7915000.0       71.60  2019-04-18T00:00:00      2
# 44               13   5350000.0       40.00  2018-11-18T00:00:00      1
# 45               17   5200000.0       50.60  2018-12-02T00:00:00      2
# 46               17   6600000.0       52.10  2019-01-31T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23684            20  21400000.0      145.00  2018-11-02T00:00:00      4
# 23685            15   2490000.0       31.00  2019-01-24T00:00:00      1
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
#Отсутсвие данных о балконе наверняка означает его отсутствие (вообще на Яндекс.Недвижимость нельзя указать кол-во балконов))
df['balcony'].fillna(value=0,inplace=True)

# Думаю, многие не знали о существовании аппартаментов, тем более в то время они были не так популярны, поэтому Nan == False
df['is_apartment'].fillna(value=False, inplace=True)

# Объявления выставлены в разное время(а не в день исследования), так что это не новые объявления, а забытые, оставим как есть
df[df['days_exposition'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 7                 5   7915000.0       71.60  2019-04-18T00:00:00      2
# 44               13   5350000.0       40.00  2018-11-18T00:00:00      1
# 45               17   5200000.0       50.60  2018-12-02T00:00:00      2
# 46               17   6600000.0       52.10  2019-01-31T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23684            20  21400000.0      145.00  2018-11-02T00:00:00      4
# 23685            15   2490000.0       31.00  2019-01-24T00:00:00      1
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
df.duplicated().sum() # Очевидных дубликатов нет
# Out:
# 0

# %%
df['locality_name'].sort_values().unique() #Дубликатов я тут не заметил, но очень много значений для человеческого глаза
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# Заменим типы некоторых столбцов на удобные нам

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S') # C этим форматом проще работать
df['days_exposition'] = df[df['days_exposition'].notna()]['days_exposition'].astype('int') # Потому что считаются целые дни
df['balcony'] = df['balcony'].astype('int') # Я не часто бываю в Питере, но половины балкона там не замечал
df['last_price'] = df['last_price'].astype('int') # Я бы вообще перевел в млны, но лучше просто убрать дроби

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# ### Выводы ###
#
# С данных оказалось множество пропусков, часть из них нам удалось заменить: кол-во балконов, тип квартиры, дни публикации.
# Остальные либо заменены не полностью, либо оставлены в изначальном виде

# %%
sns.heatmap(df.corr());

# %%
(df
    .pivot_table(index='living_area', values='total_area',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='o', grid=True)
);
plt.title('Зависимость жилой площади от общей площади недвижимости')
plt.xlabel('Жилая площадь')
plt.ylabel('Общая площадь')
df['living_area'].corr(df['total_area'])
# Out:
# 0.9395373338721498

# %%
# Посчитаем и добавим столбик с процентным соотнощением жилой/кухни к общей площади.
#p.s. не стал удалять эти же строки в следующем задании, чтобы не ломать повествование и заполнить потом пропуски и там
df['living_to_total_area'] = round(df['living_area'] / df['total_area'],2)
df['kithen_to_total_area'] = round(df['kitchen_area'] / df['total_area'],2)

# %%
df['living_area'] = round(df['living_area'].fillna(df['living_to_total_area'].mean() * df['total_area']), 1) 
df['kitchen_area'] = round(df['kitchen_area'].fillna(df['kithen_to_total_area'].mean() * df['total_area']), 1)

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height             78
# floors_total               86
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# until_center_km          5519
# living_to_total_area     1903
# kithen_to_total_area     2278
# dtype: int64

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Добавим в таблицу столбцы с днем недели, месяцем, и годом объявления

# %%
df['weekday'] = df['first_day_exposition'].dt.weekday
df['month'] = df['first_day_exposition'].dt.month
df['year'] = df['first_day_exposition'].dt.year

# %% [markdown]
# А так же цену за квадратный метр

# %%
df['price_per_meter'] = round(df['last_price'] / df['total_area'],2)

# %% [markdown]
# Добавим еще столбец с указанием: первый, последний или другой этаж

# %%
def floors(row):
    floor = row['floor']
    floors_total = row['floors_total']
    if floor == 1:
        return 'первый'
    if floor == floors_total:
        return 'последний'
    return 'другой'

df['floor_category'] = df.apply(floors, axis=1)

# %% [markdown]
# И соотношение метража кухни/жилого к общему

# %%
df['living_to_total_area'] = round(df['living_area'] / df['total_area'],2)
df['kithen_to_total_area'] = round(df['kitchen_area'] / df['total_area'],2)

# %% [markdown]
# Теперь, когда у нас есть нужные столбцы, можем  убрать лишние для удобства

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
#df_optional = df[df.columns[[0,6,7,8,9,10,11,12,13,15,16,-1,-2,-10,-11,-12,-13]]].copy()
#df = df.drop(df.columns[[0,6,7,8,9,10,11,12,13,15,16,-1,-2,-10,-11,-12,-13]], axis=1)
#df

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение параметров квартир: площадь, цена, число комнат, высота потолков.

# %% [markdown]
# Согласно СНиП: высота потолков должна быть не менее 2.5м, что возьмем за нижнюю границу, за верхнюю возьмем сталинские высотки, в которых высота потолков может достигать 3.5м

# %%
'''(df.query('2.5 <= ceiling_height < 3.5')
    .hist(column=['total_area','rooms','last_price','ceiling_height'],bins=50,figsize=(16,9))
);'''

df.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по общей площади')
plt.xlabel('Общая площадь')
plt.ylabel('Частота')

df.plot(y = 'rooms', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по количеству комнат')
plt.xlabel('Кол-во комнат')
plt.ylabel('Частота')

df.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по цене')
plt.xlabel('Цена')
plt.ylabel('Частота')

df.plot(y = 'ceiling_height', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по высоте потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Частота');

(df
    .query('2.5 <= ceiling_height < 3.5')[['total_area','rooms','last_price','ceiling_height']]
    .describe()
)
# Out:
#          total_area         rooms    last_price  ceiling_height
# count  23132.000000  23132.000000  2.313200e+04    23132.000000
# mean      59.264994      2.048591  6.302744e+06        2.690631
# std       33.044086      1.049659  1.012342e+07        0.184657
# min       12.000000      0.000000  1.219000e+04        2.500000
# 25%       40.000000      1.000000  3.400000e+06        2.550000
# 50%       51.600000      2.000000  4.600000e+06        2.650000
# 75%       68.700000      3.000000  6.650000e+06        2.750000
# max      900.000000     19.000000  7.630000e+08        3.490000

# %%
#df['total_area'].plot(kind='box',figsize=(5,5), grid=True);
#df['total_area'].plot(kind='hist',figsize=(5,5), grid=True, range=(0,100), bins=100);
#plt.ylim(0, 200)

# %%
#df['rooms'].plot(kind='box',figsize=(5,5), grid=True);
#df['rooms'].plot(kind='hist',figsize=(5,5), grid=True, range=(0,6), bins=100);

# %%
#df['last_price'].plot(kind='box',figsize=(5,5), grid=True);
#df['last_price'].plot(kind='hist',figsize=(5,5), grid=True, bins=100, range=(0,2e7));
#plt.ylim(0, 1.25e7)

# %%
#df['ceiling_height'].plot(kind='box',figsize=(5,5), grid=True);
#df['ceiling_height'].plot(kind='hist',figsize=(5,5), grid=True, bins=100, range=(2,4));
#plt.ylim(0, 4)

# %% [markdown]
# На всех графиках у нас есть высокий пик с длинным хвостом, который, однако, не сильно утягивает среднее значение от медианы. Вцелом данные впорядке.
#
# Также я построил диаграмму размаха, чтобы определить редкие значения среди данных параметров

# %% [markdown]
# ### Изучение времени продажи квартир

# %%
df['days_exposition'].hist(bins=100, range=(1,1600));
plt.title('Распределение по длительности продажи')
plt.xlabel('Время активности объявления')
plt.ylabel('Частота');
df.query('days_exposition != 0')['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Распределение похоже на паусонновское. В среднем продажа квартиры занимает 180 дней, медианное значение - 95 дней. Межквартильное расстояние - от 45 до 232 дней.

# %%
df.query('days_exposition != 0')['days_exposition'].plot(kind='box',figsize=(9,9), grid=True);
plt.title('Диаграмма размаха длительности продажи')
plt.ylabel('Время активности объявления');

# %% [markdown]
# Исходя из значений boxplot- аномально долгими считаются объявления более 500 дней, аномально быстрые- отсутствуют.

# %% [markdown]
# Рассмотрим этот промежуток внимательнее

# %% [markdown]
# ### Удаление редких и выбивающихся значений

# %%
df['days_exposition'].hist(bins=100, range=(1,500));
plt.title('Распределение по длительности продажи')
plt.xlabel('Время активности объявления')
plt.ylabel('Частота');

# %% [markdown]
# Видно аномальные пики на 45, 60 и 90 день. А так же на 7 и 30 **(тут есть и аренда?)**
#
# Мне подсказали, что в правилах Яндекс.Недвижимости есть сроки годности объявлений в зависимости от стоимости. https://yandex.ru/support/realty/owner/home/add-ads-housing.html

# %%
pd.DataFrame({
    'Вид объекта': ['Квартира', 'Квартира','Квартира', 'Комната', 'Дом и участок'],
    'Продажа': ['до 4,5 млн — 45 дней', 'от 4,5 до 10 млн — 60 дней', 'от 10 млн — 90 дней', '45 дней', '90 дней'],
    'Аренда длительная': ['до 20 тыс/м — 7 дней', 'от 20 до 40 тыс/м — 14 дней', 'от 40 тыс/м — 21 день', '7 дней', '30 дней'],
})
# Out:
#      Вид объекта                     Продажа            Аренда длительная
# 0       Квартира        до 4,5 млн — 45 дней         до 20 тыс/м — 7 дней
# 1       Квартира  от 4,5 до 10 млн — 60 дней  от 20 до 40 тыс/м — 14 дней
# 2       Квартира         от 10 млн — 90 дней        от 40 тыс/м — 21 день
# 3        Комната                     45 дней                       7 дней
# 4  Дом и участок                     90 дней                      30 дней

# %% [markdown]
# (...правда, потом я увидел, что для СПБ и области другие сроки, но надеюсь, что так сделали недавно, иначе эти пики необъяснимы для меня)

# %% [markdown]
# Уберем объявления, которые похожи на просрочку, оставив при этом те, которые точно продались в эти дни.

# %%
#Например: 
print('Количество просроченых объявлений на 60 день равно:', len(df.query('days_exposition == 60 and 4.5e6 < last_price < 10e6')))
print('Всего объявлений снятых на 60 день равно:', len(df.query('days_exposition == 60')))
# Out:
# Количество просроченых объявлений на 60 день равно: 471
# Всего объявлений снятых на 60 день равно: 538

# %%
good_days_exposition = df.query('days_exposition != 0' # Мы присвоили NaN'ам 0, так что они нам не подходят
    'and not(days_exposition == 7 and price_per_meter < 2e4)' # Уберем просроченные объявления среди аренды
    'and not(days_exposition == 14 and 2e4 < price_per_meter < 4e4)' 
    'and not(days_exposition == 21 and 4e4 < price_per_meter)'               
    'and not(days_exposition == 45 and last_price < 4.5e6)' 
    'and not(days_exposition == 60 and 4.5e6 < last_price < 10e6)' 
    'and not(days_exposition == 90 and 10e6< last_price)' 
    )

# %%
good_days_exposition['days_exposition'].hist(bins=100, range=(0,500));
plt.title('Распределение по длительности продажи')
plt.xlabel('Время активности объявления')
plt.ylabel('Частота');

# %% [markdown]
# Теперь в гистограмме нет паталогических пиков, распределение- пауссоновское.

# %%
good_days_exposition['days_exposition'].plot(kind='box',figsize=(5,5), grid=True);
plt.ylim(0,600)
plt.title('Распределение по длительности продажи')
plt.ylabel('Время активности объявления')
# Out:
# Text(0, 0.5, 'Время активности объявления')

# %% [markdown]
# Теперь максимально долго допустимые сроки объявления среди у нас до 550 дней.

# %%
f'Мы удалили {len(df) - len(good_days_exposition)} строк из исходного датафрейма, что составило {1 - (len(good_days_exposition)/len(df)):.2%}'
# Out:
# 'Мы удалили 1570 строк из исходного датафрейма, что составило 6.62%'

# %% [markdown]
# ### Исследование факторов наиболее влияющих на стоимость квартир

# %% [markdown]
# #### Влияние площади недвижимости на цену за квадратный метр

# %%
# Создадим новый дф, освобожденный от выбросов
good_df =df.query('total_area <= 125' # Отсечем редкие значения в остальных столбцах
    'and rooms < 6' 
    'and 2.5 <= ceiling_height <= 3.5' 
    'and last_price <= 1.2e7'  
    )

# %%
f'Мы удалили {len(df) - len(good_df)} строк из исходного датафрейма, что составило {1 - (len(good_df)/len(df)):.2%}'
# Out:
# 'Мы удалили 2329 строк из исходного датафрейма, что составило 9.83%'

# %%
(good_df
    .pivot_table(index='total_area', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='o', grid=True)
);
plt.title('Зависимость общей площади и цены')
plt.ylabel('Цена')
plt.xlabel('общая площадь');
good_df['total_area'].corr(good_df['last_price'])
# Out:
# 0.7023880097846232

# %% [markdown]
# Очевидно, что чем больще площадь, тем выше цена. Корреляция равно 0.7

# %% [markdown]
# #### Влияние количества комнат недвижимости на цену за квадратный метр

# %%
(good_df
    .pivot_table(index='rooms', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='-o', grid=True)
);
plt.title('Зависимость количества комнат и цены')
plt.ylabel('Цена')
plt.xlabel('Количество комнат');
good_df['rooms'].corr(good_df['last_price'])
# Out:
# 0.44208079166440556

# %% [markdown]
# Опять-таки, что логично, с увеличением числа комнат растет и стоимость жилья

# %% [markdown]
# #### Влияние расстояния недвижимости до центра города на цену за квадратный метр

# %%
(good_df
    .pivot_table(index='until_center_km', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='-o', grid=True)
);
plt.title('Зависимость расстояния до центра города и цены')
plt.ylabel('Цена')
plt.xlabel('Расстояние до центра');
good_df['until_center_km'].corr(good_df['last_price'])
# Out:
# -0.3425489355309574

# %% [markdown]
# Расстояние до центра города уже влияет на стоимость: так начиная с 10км стоимость квартир резко возрастнает, однако есть и дорогие загородные дома

# %% [markdown]
# #### Влияние этажа на цену за квадратный метр

# %%
(good_df
    .pivot_table(index='floor_category', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='-o', grid=True)
);
plt.title('Зависимость этажа и цены')
plt.ylabel('Цена')
plt.xlabel('Этаж');
good_df.pivot_table(index='floor_category', values='last_price',aggfunc=['median','count'])
# Out:
#                    median      count
#                last_price last_price
# floor_category
# другой            4580000      15662
# первый            3800000       2767
# последний         4000000       2941

# %% [markdown]
# Вцелом первый и последний этажи стоят дешевле других, при этом первый этаж- самый дешевый

# %% [markdown]
# #### Влияние дня недели размещения объявления на цену за квадратный метр

# %%
(good_df
    .pivot_table(index='weekday', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='-o', grid=True)
);
plt.title('Зависимость дня недели размещения объявления и цены')
plt.ylabel('Цена')
plt.xlabel('День недели размещения объявления');
good_df.pivot_table(index='weekday', values='last_price',aggfunc=['median','count'])
# Out:
#             median      count
#         last_price last_price
# weekday
# 0          4400000       3251
# 1          4490000       3789
# 2          4450000       3565
# 3          4400000       3819
# 4          4350000       3632
# 5          4400000       1764
# 6          4390000       1550

# %% [markdown]
# Забавно, что во вторник выставляются самые дорогие квартиры, и далее, до выходных цена падает, вновь поднимаясь с пятницы до вторника.
#
# Это люди в такое уныние от работы впадают, что обесценивают своё имущество?

# %% [markdown]
# #### Влияние месяца размещения объявления на цену за квадратный метр

# %%
(good_df
    .pivot_table(index='month', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='-o', grid=True)
);
plt.title('Зависимость месяца недели размещения объявления и цены')
plt.ylabel('Цена')
plt.xlabel('Месяц размещения объявления');
good_df.pivot_table(index='month', values='last_price',aggfunc=['median','count'])
# Out:
#           median      count
#       last_price last_price
# month
# 1        4400000       1347
# 2        4400000       2392
# 3        4400000       2334
# 4        4550000       2147
# 5        4350000       1142
# 6        4200000       1598
# 7        4350000       1519
# 8        4350000       1579
# 9        4400000       1772
# 10       4400000       1928
# 11       4450000       2124
# 12       4490000       1488

# %% [markdown]
# Судя про графику: невыгоднее всего продавать квартиру в июне, а вот непосредственно перед отпусками- в апреле, самые высокие цены на недвижимость

# %% [markdown]
# #### Влияние года размещения объявления на цену за квадратный метр

# %%
(good_df
    .pivot_table(index='year', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='-o', grid=True)
);
plt.title('Зависимость года размещения объявления и цены')
plt.ylabel('Цена')
plt.xlabel('Год размещения объявления');
good_df.pivot_table(index='year', values='last_price',aggfunc=['median','count'])
# Out:
#          median      count
#      last_price last_price
# year
# 2014    5500000         89
# 2015    4855500        996
# 2016    4300000       2461
# 2017    4290000       7409
# 2018    4390000       7822
# 2019    4800000       2593

# %% [markdown]
# С 2014 по 2016 года стоимость квадратного метра падала, а затем начала подниматься, что делает и по сей день(
# Думаю, всё дело в том, что на 2014-2015гг - пришёлся валютный кризис в РФ, и спрос на жилье упал, что повлекло снижение стоимости и самого жилья

# %% [markdown]
# ### Выводы

# %% [markdown]
# Проанализировав данные можно заключить, что на стоимость квадратного метра больше всего влияет расстояние до центра города и этаж, а так же сезонность.
# *  Самые дешевые объявления выставляются в субботу в мае-июне, а самые дорогие- по апрельским вторникам;
# *  Первый и последний этажи дешевле остальных;
# *  С 2016 года цены в среднем растут;
# *  Количество комнат и общая площадь квартиры почти не влияют на цену за квадратный метр;

# %% [markdown]
# ## Исследование цен на недвижимость в Санкт_Петербурге

# %% [markdown]
# Определим населенные пункты с самой высокой и низкой стоимостью жилья среди 10 лидеров по кол-ву объявлений

# %%
df_most_count = (good_df
.pivot_table(index='locality_name', values='last_price', aggfunc=('count','mean'))
.sort_values('count',ascending=False)
).head(10)
df_most_count
# Out:
#                      count          mean
# locality_name
# Санкт-Петербург    13567.0  5.670606e+06
# посёлок Мурино       520.0  3.671211e+06
# посёлок Шушары       438.0  4.090295e+06
# Всеволожск           392.0  3.709276e+06
# Колпино              334.0  3.829609e+06
# Пушкин               331.0  5.329553e+06
# посёлок Парголово    325.0  4.482463e+06
# Гатчина              302.0  3.409074e+06
# деревня Кудрово      298.0  4.204742e+06
# Выборг               225.0  3.109089e+06

# %%
print('Населенный пункт с самой высокой стоимостью жилья:')
df_most_count[df_most_count['mean']==df_most_count['mean'].max()].reset_index()
# Out:
# Населенный пункт с самой высокой стоимостью жилья:
#      locality_name    count          mean
# 0  Санкт-Петербург  13567.0  5.670606e+06

# %%
print('Населенный пункт с самой низкой стоимостью жилья:')
df_most_count[df_most_count['mean']==df_most_count['mean'].min()].reset_index()
# Out:
# Населенный пункт с самой низкой стоимостью жилья:
#   locality_name  count          mean
# 0        Выборг  225.0  3.109089e+06

# %% [markdown]
# Ожидаемо, самая дорогая недвижимость в Санкт-Петербурге.
# А вот дешевле всего в Выборге- городе с населением в 74000 человек

# %% [markdown]
# ### Определение центра СПБ

# %% [markdown]
# Создадим таблицу с объявлениями в северной столице, и определим радиус центра города: так как мы знаем, что цена зависит от расстояния до центра, значит резкий скачек в цене будет означать его границы

# %%
good_df['until_center_km'].dropna(inplace=True)
# Out:
# D:\Programs\anaconda\lib\site-packages\pandas\core\series.py:5258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)

# %%
(df.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='until_center_km',values='last_price',aggfunc='mean')
    .plot(grid=True)
);
plt.title('Зависимость расстояния до центра города и цены')
plt.ylabel('Цена')
plt.xlabel('Расстояние до центра');

# %% [markdown]
# Центр города- 9км, плюс скачек цен у границы города на 26км (м.б. какой-то дорогой квартал?)
# Вообще, говоря откровенно Питер не настолько большой, возможно, имеет смысл взять за центр города радиус в 3 км (что примерно соответствует его историческим районам), но для исследования буду использовать современный центр - 9км

# %%
spb_center = good_df.query('locality_name == "Санкт-Петербург" and until_center_km <= 9').copy() # Современный центр
spb_df = good_df.query('locality_name == "Санкт-Петербург" and until_center_km > 9').copy()

# %% [markdown]
# ### Исследование факторов наиболее влияющих на стоимость квартир в СПБ

# %%
'''(spb_df.query('2.5 <= ceiling_height < 3.5')
    .hist(column=['total_area','rooms','last_price','ceiling_height'],bins=50,figsize=(16,9))
);'''

spb_center.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по общей площади')
plt.xlabel('Общая площадь')
plt.ylabel('Частота')

spb_center.plot(y = 'rooms', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по количеству комнат')
plt.xlabel('Кол-во комнат')
plt.ylabel('Частота')

spb_center.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по цене')
plt.xlabel('Цена')
plt.ylabel('Частота')

spb_center.plot(y = 'ceiling_height', kind = 'hist', bins = 100, grid=True, figsize = (5,3))
plt.title('Распределение по высоте потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Частота');

(spb_center[['total_area','rooms','last_price','ceiling_height']]
    .describe()
)
# Out:
#         total_area        rooms    last_price  ceiling_height
# count  3183.000000  3183.000000  3.183000e+03     3183.000000
# mean     62.509730     2.206409  7.028079e+06        2.839070
# std      21.831396     0.965038  2.332867e+06        0.257794
# min      12.000000     0.000000  1.219000e+04        2.500000
# 25%      45.000000     1.000000  5.200000e+06        2.600000
# 50%      60.000000     2.000000  6.800000e+06        2.800000
# 75%      77.000000     3.000000  8.700000e+06        3.000000
# max     125.000000     5.000000  1.200000e+07        3.500000

# %% [markdown]
# В Питере в среднем выше потолки, интересно. А в остальном ничем не отличается от общего датафрейма.

# %%
(spb_center
    .pivot_table(index='total_area', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='o', grid=True)
);
plt.title('Зависимость общей площади и цены')
plt.ylabel('Цена')
plt.xlabel('Общая площадь');
spb_center['total_area'].corr(spb_center['last_price'])
# Out:
# 0.743478182500215

# %% [markdown]
# Никто не сомневается, что здесь присутствует положительная корреляция = 0.74

# %%
plt.plot(spb_df
    .pivot_table(index='rooms', values='last_price',aggfunc='median'), label = 'Остальной город')
plt.plot(spb_center
    .pivot_table(index='rooms', values='last_price',aggfunc='median'), label = 'Центр')
plt.title('Зависимость кол-ва комнат и цены')
plt.ylabel('Цена')
plt.xlabel('Количество комнат');
plt.legend()
plt.grid()
spb_center['rooms'].corr(spb_center['last_price'])
# Out:
# 0.49613355952481825

# %% [markdown]
# Как и в общем датафрейме- с увеличением количества комнат цена растет

# %%
(spb_center
    .pivot_table(index='until_center_km', values='last_price',aggfunc=['mean','median','count'])
    .plot(y = 'median', style='-o', grid=True)
);
plt.title('Расстояния до центра города и цены')
plt.ylabel('Цена')
plt.xlabel('Расстояние до центра города');
spb_center['until_center_km'].corr(spb_center['last_price'])
# Out:
# -0.2975439346763421

# %% [markdown]
# Как я писал выше, в городе два центра: исторический- 3км и современный- 9км.

# %%
plt.plot(spb_df
    .pivot_table(index='floor_category', values='last_price',aggfunc='median'), label = 'Остальной город')
plt.plot(spb_center
    .pivot_table(index='floor_category', values='last_price',aggfunc='median'), label = 'Центр')
plt.title('Зависимость этажа и цены')
plt.ylabel('Цена')
plt.xlabel('Этаж');
plt.legend()
plt.grid()
spb_center.pivot_table(index='floor_category', values='last_price',aggfunc=['median','count'])
# Out:
#                    median      count
#                last_price last_price
# floor_category
# другой            7000000       2266
# первый            5825000        408
# последний         6800000        509

# %% [markdown]
# Первый < Последний < Другой

# %%
plt.plot(spb_df
    .pivot_table(index='weekday', values='last_price',aggfunc='median'), label = 'Остальной город')
plt.plot(spb_center
    .pivot_table(index='weekday', values='last_price',aggfunc='median'), label = 'Центр')
plt.title('Зависимость дня недели и цены')
plt.ylabel('Цена')
plt.xlabel('День недели');
plt.legend()
plt.grid()
spb_center.pivot_table(index='weekday', values='last_price',aggfunc=['median','count'])
# Out:
#             median      count
#         last_price last_price
# weekday
# 0          6800000        470
# 1          6800000        572
# 2          6800000        530
# 3          6799500        620
# 4          6850000        547
# 5          6800000        248
# 6          7250000        196

# %% [markdown]
# А вот день недели на стоимость квартир в центре уже влияет немного иначе: всё так же самые дорогие объявления выставляют в выходные, однако в остальную неделю этой зависимости почти нет

# %%
plt.plot(spb_df
    .pivot_table(index='month', values='last_price',aggfunc='median'), label = 'Остальной город')
plt.plot(spb_center
    .pivot_table(index='month', values='last_price',aggfunc='median'), label = 'Центр')
plt.title('Зависимость месяца и цены')
plt.ylabel('Цена')
plt.xlabel('Месяц');
plt.legend()
plt.grid()
spb_center.pivot_table(index='month', values='last_price',aggfunc=['median','count'])
# Out:
#           median      count
#       last_price last_price
# month
# 1        6825000        194
# 2        6700000        343
# 3        6756696        338
# 4        6950000        315
# 5        6880000        193
# 6        6740000        249
# 7        6850000        244
# 8        6997000        241
# 9        7400000        273
# 10       6725000        278
# 11       6800000        287
# 12       6650000        228

# %% [markdown]
# Сезоность наблюдается и в центре Питера, но здесь самые дорогие квартиры в сентябре, а дешевле всего в октябре.

# %%
plt.plot(spb_df
    .pivot_table(index='year', values='last_price',aggfunc='median'), label = 'Остальной город')
plt.plot(spb_center
    .pivot_table(index='year', values='last_price',aggfunc='median'), label = 'Центр')
plt.title('Зависимость года и цены')
plt.ylabel('Цена')
plt.xlabel('Год');
plt.legend()
plt.grid()
spb_center.pivot_table(index='year', values='last_price',aggfunc=['median','count'])
# Out:
#          median      count
#      last_price last_price
# year
# 2014    7500000         15
# 2015    7104630        232
# 2016    6850000        404
# 2017    6750000       1117
# 2018    6800000       1059
# 2019    6970000        356

# %% [markdown]
# К сожалению, кризис затрагивает население всей страны, так что здесь данные идентичны, хотя центр Питера практически не потерял свои позиции

# %% [markdown]
# ### Выводы

# %% [markdown]
# Зависимость цены недвижимости от её параметров такая же как и по всей выборке, однако сезонность в большом городе протекает немного иначе:
#  *  Люди склонны поднимать цену за квадратный метр втечение недели, достигая пика на выходных, а не в начале недели, как в общем графике;
#  *  Самый неудачный месяц для продажи октябрь, а удачный  - сентябрь, однако в мае питербуржцы оценивают свою недвижимость выше, чем в области;

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Мы обработали данные Яндекс.Недвижимости, удалили дубликаты и заполнили пропуски, изменили типы ячеек, там, где это было необходимо. Посчитали и добавили в таблицу цену квадратного метра, день недели, месяц и год публикации объявления а так же этаж квартиры, относительно этажности дома.
# Были изучены параметры квартир: площадь, цена, число комнат, высота потолков, в которых обнаружены аномалии.
# Исследуя время продажи квартиры, мы обнаружили выбивающиеся значения: большинство объявлений были сняты на 45,60 и 90 дни, что оказалось датой автоматического снятия публикации. Мы отфильтровали эти объявления по правилам Яндекс.Недвижимости и удалили неподходящие значения. В ходе исследования мы использовали графих размаха и было установлено, что нормальный промежуток времени в который продается недвижимость- от 1 до 550 дней.
# Мы выявили, что на стоимость квадратного метра квартиры больше всего влияют количество комнат, этаж квартиры, близость к центру. Незначительно на стоимость квадратного метра влияют день, месяц, год размещения и общая площадь.
# *  Самые дешевые объявления выставляются в субботу в мае-июне, а самые дорогие- по апрельским вторникам;
# *  Первый и последний этажи дешевле остальных;
# *  С 2016 года цены в среднем растут;
# *  Количество комнат и общая площадь квартиры почти не влияют на цену за квадратный метр;А так же, снижение цен на недвижимость в связи с кризисом 2014-2015 гг, с последующим восстановлением и ростом цен по сегодняшний день.
#
# Аналогичные данные мы обнаружили и по недвижимости в центре Санкт-Петербурга, за небольшим исключением:
#  *  Люди склонны поднимать цену за квадратный метр втечение недели, достигая пика на выходных, а не в начале недели, как в общем графике;
#  *  Самый неудачный месяц для продажи по-прежнему - июнь, а удачный по-прежнему - апрель, однако в мае питербуржцы оценивают свою недвижимость выше, чем в области;
